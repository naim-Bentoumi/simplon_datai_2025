# %% [markdown]
# # EXERCICE DU 15/09/2023
#
# ### Exercice 1
#
# Faire un générateur de nombre aléatoire pour le loto et l'euromillion. Attention c’est un tirage aléatoire sans remise (c.a.d que la boule trouvée n’est pas remise en jeu) et tous les chiffres ont la même probabilité d’apparaître.

# %%
import numpy as np

def loto():
    a = np.random.choice(np.arange(1,50),5, replace=False)
    b = np.random.choice(np.arange(1,11),1)

    print("Les 5 premiers numéros sont : " + str(a[0]) + ", " + str(a[1]) + ", " + str(a[2]) + ", " + str(a[3]) + " et " + str(a[4]) + " !" + "\nLe numéro complémentaire est : " + str(b[0]) + " !")

def euro_milion():
    a = np.random.choice(np.arange(1,51),5, replace=False)
    b = np.random.choice(np.arange(1,13),2, replace=False)

    print("Les 5 premiers numéros sont : " + str(a[0]) + ", " + str(a[1]) + ", " + str(a[2]) + ", " + str(a[3]) + " et " + str(a[4]) + " !" + "\nLes numéros complémentaires sont : " + str(b[0]) + " et " + str(b[1]) +  " !")

loto()
euro_milion()
# Out:
# Les 5 premiers numéros sont : 2, 28, 37, 14 et 23 !
# Le numéro complémentaire est : 4 !
# Les 5 premiers numéros sont : 37, 22, 44, 19 et 31 !
# Les numéros complémentaires sont : 10 et 4 !

# %% [markdown]
# ### Exercice 2
#
# Reprenez l’exercice 16 et faites en sorte que le nombre à trouver soit aléatoire et compris entre 1 et 1000:
# “Écrivez un programme qui demande à l'utilisateur de deviner un nombre secret (par exemple 42). Le programme indique à l'utilisateur si le nombre à deviner est plus grand ou plus petit que sa proposition et continue de demander un nombre tant que l'utilisateur ne trouve pas le nombre secret. Une fois que l'utilisateur trouve le nombre secret, affichez un message de félicitations.”

# %%
import numpy as np

def JustePrix():
    num = np.random.randint(1, 1000)
    guess = 0
    while guess != num:
        guess = int(input("Choisis un nombre : "))
        if guess == num:
            print("Felicitation !")
        elif guess > num:
            print("C'est moins")
        else:
            print("C'est plus")

JustePrix()
# Out:
# Choisis un nombre : 500
# C'est moins
# Choisis un nombre : 250
# C'est plus
# Choisis un nombre : 375
# C'est moins
# Choisis un nombre : 313
# C'est moins
# Choisis un nombre : 232
# C'est plus
# Choisis un nombre : 282
# C'est moins
# Choisis un nombre : 277
# C'est moins
# Choisis un nombre : 263
# C'est plus
# Choisis un nombre : 270
# C'est plus
# Choisis un nombre : 274
# C'est moins
# Choisis un nombre : 272
# C'est plus
# Choisis un nombre : 273
# Felicitation !

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [1, 4, 3, 8, 5]


plt.plot(x,y,"b")
plt.xlabel("Heure")
plt.ylabel("Fatigue")
plt.title("Graphique de ma fatigue")
plt.annotate('Pause', xy=(3.5,7), xytext=(4.5,7), arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(4.5, 7, 'Pause')

# %%
import numpy as np
z = np.random.randn(10000)

plt.title("Graphique de ma fatigue")
plt.hist(z,color="red")
plt.show()
plt.close('all')

# %%
categories = ['A', 'B', 'C', 'D', 'E']
valeurs = [25, 30, 15, 20, 10]

plt.bar(categories, valeurs, color="purple")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.plot(np.random.randint(1,100,100),np.random.randint(1,100,100),'go')

# %%
t2 = np.arange(0.0, 5.0, 0.02)
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.subplot(211)
plt.plot(x, y1, 'bo',x, y2, 'k--')
plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'y^')

# %%
categories = ['A', 'B', 'C', 'D']
valeurs = [30, 25, 15, 20]

plt.pie(valeurs, labels = categories, shadow= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x23af2deaf90>,
#   <matplotlib.patches.Wedge at 0x23af2deb8d0>,
#   <matplotlib.patches.Wedge at 0x23af2df9290>,
#   <matplotlib.patches.Wedge at 0x23af2dfab90>],
#  [Text(0.5499999702695115, 0.9526279613277875, 'A'),
#   Text(-1.0832885481844534, 0.19101288273940947, 'B'),
#   Text(-0.3762219909843025, -1.0336619435288346, 'C'),
#   Text(0.8426490161537282, -0.7070662172492433, 'D')])

# %%
x = np.linspace(-5, 5, 100)
y = 3 * x**3 + 2 * x**2 - 8 * x + 5


plt.plot(x,y, 'r')
plt.grid(True)

# %%
categories = ['A', 'B', 'C', 'D']
valeurs1 = [10, 15, 20, 25]
valeurs2 = [5, 10, 15, 20]


plt.bar(categories, valeurs1)
plt.bar(categories, valeurs2)
# Out:
# <BarContainer object of 4 artists>

# %%
data = [np.random.normal(0, 1, 100), np.random.normal(2, 1, 100), np.random.normal(-3, 2, 100)]

plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23aee872c90>,
#   <matplotlib.lines.Line2D at 0x23aee830050>,
#   <matplotlib.lines.Line2D at 0x23aee868990>,
#   <matplotlib.lines.Line2D at 0x23aee86aa90>,
#   <matplotlib.lines.Line2D at 0x23aee866590>,
#   <matplotlib.lines.Line2D at 0x23aee8d4f10>],
#  'caps': [<matplotlib.lines.Line2D at 0x23aee831b50>,
#   <matplotlib.lines.Line2D at 0x23aee86a210>,
#   <matplotlib.lines.Line2D at 0x23aee849810>,
#   <matplotlib.lines.Line2D at 0x23aee849410>,
#   <matplotlib.lines.Line2D at 0x23aee8d7290>,
#   <matplotlib.lines.Line2D at 0x23aeea6e290>],
#  'boxes': [<matplotlib.lines.Line2D at 0x23aee7c07d0>,
#   <matplotlib.lines.Line2D at 0x23aee86b050>,
#   <matplotlib.lines.Line2D at 0x23aee864e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x23aee86b890>,
#   <matplotlib.lines.Line2D at 0x23aee867bd0>,
#   <matplotlib.lines.Line2D at 0x23aecd59210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23aee869150>,
#   <matplotlib.lines.Line2D at 0x23aee864d10>,
#   <matplotlib.lines.Line2D at 0x23aee8cef90>],
#  'means': []}
